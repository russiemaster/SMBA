# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
df = pd.read_csv('/content/Final_data set.csv',encoding='cp1252')

# %%
df.head(5)
# Out:
#    HDI rank                 Country  Human Development Index (HDI)(2019)  \
# 0         1                  Norway                                0.957
# 1         2                 Ireland                                0.955
# 2         2             Switzerland                                0.955
# 3         4  Hong Kong, China (SAR)                                0.949
# 4         4                 Iceland                                0.949
#
#    Inequality-adjusted HDI (IHDI)(2019)  Overall loss (%)(2019)  \
# 0                                 0.899                     6.1
# 1                                 0.885                     7.3
# 2                                 0.889                     6.9
# 3                                 0.824                    13.2
# 4                                 0.894                     5.8
#
#    Difference from HDI rank(2019)  Coefficient of human inequality(2019)  \
# ...

# %%
h=corrmat.index
g=sns.heatmap(df[h].corr(),annot=True,cmap="RdYlGn")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-75fc70bcd0b6> in <module>()
# ----> 1 h=corrmat.index
#       2 g=sns.heatmap(df[h].corr(),annot=True,cmap="RdYlGn")
#
# NameError: name 'corrmat' is not defined

# %%
df.isnull().sum()
# Out:
# HDI rank                                            0
# Country                                             0
# Human Development Index (HDI)(2019)                 0
# Inequality-adjusted HDI (IHDI)(2019)               37
# Overall loss (%)(2019)                             37
# Difference from HDI rank(2019)                     37
# Coefficient of human inequality(2019)              37
# Inequality in life expectancy(%)(2015-20)           6
# Inequality-adjusted life expectancy index(2019)     6
# Inequality in education(%)(2019)                   18
# Inequality-adjusted education index(2019)          18
# Inequality in income(%)(2019)                      33
# Inequality-adjusted income index(2019)             33
# Income of Poorest 40 percent (%)(2010-2018)        37
# Income of Richest 10 percent (%)(2010-2018)        37
# Income of Richest 1 percent (%)(2010-2017)         71
# Gini coefficient (2010-2018)                       37
# dtype: int64

# %%
df.describe()
# Out:
#          HDI rank  Human Development Index (HDI)(2019)  \
# count  189.000000                           189.000000
# mean    94.783069                             0.722423
# std     54.754486                             0.149791
# min      1.000000                             0.394000
# 25%     48.000000                             0.602000
# 50%     95.000000                             0.740000
# 75%    142.000000                             0.829000
# max    189.000000                             0.957000
#
#        Inequality-adjusted HDI (IHDI)(2019)  Overall loss (%)(2019)  \
# count                            152.000000              152.000000
# mean                               0.595250               19.388816
# std                                0.190002                9.953019
# min                                0.232000                4.400000
# 25%                                0.431500               10.775000
# ...

# %%
#cols = [2,3,16,17,5,18,19,20]
#X=df[df.columns[cols]]
#Y=df.iloc[:, 20]

# %%
for col in list(df.columns):
    if df[col].dtypes == 'float64':
        df[col] = df[col].fillna(df[col].mean())
    else:
        df[col] = df[col].fillna(df[col].max())

# %%
df.isnull().sum()
# Out:
# HDI rank                                           0
# Country                                            0
# Human Development Index (HDI)(2019)                0
# Inequality-adjusted HDI (IHDI)(2019)               0
# Overall loss (%)(2019)                             0
# Difference from HDI rank(2019)                     0
# Coefficient of human inequality(2019)              0
# Inequality in life expectancy(%)(2015-20)          0
# Inequality-adjusted life expectancy index(2019)    0
# Inequality in education(%)(2019)                   0
# Inequality-adjusted education index(2019)          0
# Inequality in income(%)(2019)                      0
# Inequality-adjusted income index(2019)             0
# Income of Poorest 40 percent (%)(2010-2018)        0
# Income of Richest 10 percent (%)(2010-2018)        0
# Income of Richest 1 percent (%)(2010-2017)         0
# Gini coefficient (2010-2018)                       0
# dtype: int64

# %%
a=df.corr()
a
# Out:
#                                                  HDI rank  \
# HDI rank                                         1.000000
# Human Development Index (HDI)(2019)             -0.990231
# Inequality-adjusted HDI (IHDI)(2019)            -0.923527
# Overall loss (%)(2019)                           0.832937
# Difference from HDI rank(2019)                   0.081913
# Coefficient of human inequality(2019)            0.838846
# Inequality in life expectancy(%)(2015-20)        0.893161
# Inequality-adjusted life expectancy index(2019) -0.916536
# Inequality in education(%)(2019)                 0.789750
# Inequality-adjusted education index(2019)       -0.900095
# Inequality in income(%)(2019)                    0.383155
# Inequality-adjusted income index(2019)          -0.883213
# Income of Poorest 40 percent (%)(2010-2018)     -0.371601
# Income of Richest 10 percent (%)(2010-2018)      0.431678
# Income of Richest 1 percent (%)(2010-2017)       0.305641
# ...

# %%
cols = [6,11,13,14]
X=df[df.columns[cols]]
Y=df.iloc[:, 16]

# %%
diag = sns.pairplot(df,vars=['Coefficient of human inequality(2019)','Inequality in income(%)(2019)','Income of Poorest 40 percent (%)(2010-2018)','Income of Richest 10 percent (%)(2010-2018)','Gini coefficient (2010-2018)'],size=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
cols = [6,11,13,14]
X=df[df.columns[cols]]
Y=df.iloc[:, ]

# %%
sns.boxplot(y='Inequality-adjusted education index(2019)',data=df)

# %%
sns.boxplot(y='Coefficient of human inequality(2019)',data=df)

# %%
sns.boxplot(y='Inequality in income(%)(2019)',data=df)

# %%
sns.boxplot(y='Income of Poorest 40 percent (%)(2010-2018)',data=df)

# %%
sns.boxplot(y='Income of Richest 10 percent (%)(2010-2018)',data=df)

# %%
sns.boxplot(y='Gini coefficient (2010-2018)',data=df)

# %%
from sklearn.model_selection import train_test_split
df['Gini coefficient (2010-2018)','Inequality-adjusted education index(2019)','Coefficient of human inequality(2019)','Income of Richest 10 percent (%)(2010-2018)'] = df['Gini coefficient (2010-2018)','Inequality-adjusted education index(2019)','Coefficient of human inequality(2019)','Income of Richest 10 percent (%)(2010-2018)'].astype('float64')

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3,train_size=0.7, random_state=0)

reg = LinearRegression()
reg.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
np.asarray['Income of Richest 10 percent (%)(2010-2018)']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-bdf368538b73> in <module>()
# ----> 1 np.asarray['Income of Richest 10 percent (%)(2010-2018)']
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
import statsmodels.api as sm
a=['Coefficient of human inequality(2019)'] 
b = ('Gini coefficient (2010-2018)')
a = sm.add_constant(a) 

model_1 = sm.OLS(b, a).fit() 
model_1.params 
print(model_1.summary())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-1ed2facc3376> in <module>()
#       2 a=['Coefficient of human inequality(2019)']
#       3 b = ('Gini coefficient (2010-2018)')
# ----> 4 a = sm.add_constant(a)
#       5
#       6 model_1 = sm.OLS(b, a).fit()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/tools.py in add_constant(data, prepend, has_constant)
#     303         raise ValueError('Only implementd 2-dimensional arrays')
#     304
# --> 305     is_nonzero_const = np.ptp(x, axis=0) == 0
#     306     is_nonzero_const &= np.all(x != 0.0, axis=0)
#     307     if is_nonzero_const.any():
#
# <__array_function__ internals> in ptp(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in ptp(a, axis, out, keepdims)
#    2628         else:
#    2629             return ptp(axis=axis, out=out, **kwargs)
# ...

# %%
import numpy as np
import statsmodels.api as sm
X_train = sm.add_constant(X_train)
model = sm.OLS(Y_train, X_train)

results = model.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-c90a35ee861f> in <module>()
#       2 import statsmodels.api as sm
#       3 X_train = sm.add_constant(X_train)
# ----> 4 model = sm.OLS(Y_train, X_train)
#       5
#       6 results = model.fit()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
# ...

# %%
def independent_ttest(data1, data2, alpha):
	# calculate means
	mean1, mean2 = mean(data1), mean(data2)
	# calculate standard errors
	se1, se2 = sem(data1), sem(data2)
	# standard error on the difference between the samples
	sed = sqrt(se1*2.0 + se2*2.0)
	# calculate the t statistic
	t_stat = (mean1 - mean2) / sed
	# degrees of freedom
	dof = len(data1) + len(data2) - 2
	# calculate the critical value
	cv = t.ppf(1.0 - alpha, df)
	# calculate the p-value
	p = (1.0 - t.cdf(abs(t_stat), df)) * 2.0
	# return everything
	return t_stat, df, cv, p

# %%
from sklearn.linear_model import LinearRegression
from statsmodels.stats.diagnostic import het_white
y = df['Gini coefficient (2010-2018)']
x = df[['Inequality in education(%)(2019)']]
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
white_test = het_white(model.resid,  model.model.exog)
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 4.1894193236793775, 'Test Statistic p-value': 0.12310598082978118, 'F-Statistic': 2.1081909687008715, 'F-Test p-value': 0.12435050400036306}
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
from sklearn.linear_model import LinearRegression
from statsmodels.stats.diagnostic import het_white
y = df['Gini coefficient (2010-2018)']
x = df[['Inequality in income(%)(2019)']]
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
white_test = het_white(model.resid,  model.model.exog)
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 13.992632539749337, 'Test Statistic p-value': 0.0009152472872847157, 'F-Statistic': 7.4357716768252935, 'F-Test p-value': 0.0007821518699342034}
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
